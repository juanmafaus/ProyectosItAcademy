# %% [markdown]
# # NIVEL 1
#
# ### Exercici 1
# Importa les dades de la base de dades emprada prèviament. Després de carregar les dades, mostra el model de la base de dades en Power BI.
#
# ![image.png](attachment:image.png)
#
# ### Exercici 2
# La teva empresa està interessada a avaluar la suma total del amount de les transaccions realitzades al llarg dels anys. Per a aconseguir això, s'ha sol·licitat la creació d'un indicador clau de rendiment (KPI). El KPI ha de proporcionar una visualització clara de l'objectiu empresarial d'aconseguir una suma total de 25.000 € per cada any.
#
#
# ![image-2.png](attachment:image-2.png)
#
# Como se puede observar, el monto de las transacciones del 2021 es muy superior al del 2022, tambien algo a destacar es que en el 2022 si bien no cumplió con el objetivo anual, fue por un margen muy pequeño.
# Con estos datos la recomendación sería investigar por qué en el 2022 no se cumple con el objetivo.
#
# Codigo DAX de la medida:
#
# ``
# Kpi Ej2 Nivel 1 =
# 25000
# ``
#
#
#
#
# ### Exercici 3
# Des de màrqueting et sol·liciten crear una nova mesura DAX que calculi la mitjana de suma de les transaccions realitzades durant l'any 2021. Visualitza aquesta mitjana en un mesurador que reflecteixi les vendes realitzades, recorda que l'empresa té un objectiu de 250.
#
# ![image-3.png](attachment:image-3.png)
#
# En este caso se ve claramente que en el año 2021 se cumple con el objetivo, pero no por un gran margen, se recomienda explorar opciones para generar un aumento en el valor del monto promedio.
#
# Codigo DAX de la medida:
#
# ``
# KPI Ej3 Nivel 1 =
# 250
# ``
#
# ``
# Monto medio en euros = var x = AVERAGE('S4 transactions'[amount]) return IF(ISBLANK(x),0,x)
# ``
# ### Exercici 4
# Realitza el mateix procediment que vas realitzar en l'exercici 3 per a l'any 2022.
#
# ![image-4.png](attachment:image-4.png)
#
# Aquí no se llega a cumplir con el objetivo, pero no es por un gran margen, se recomienda evaluar opciones para generar una mejora sustancial que permita cumplir con el objetivo planteado.
#
# Codigo DAX de la medida:
#
# ``
# KPI Ej3 Nivel 1 =
# 250
# ``
#
# ``
# Monto medio en euros = var x = AVERAGE('S4 transactions'[amount]) return IF(ISBLANK(x),0,x)
# ``
#
# ### Exercici 5
# L'objectiu d'aquest exercici és crear una KPI que visualitzi la quantitat d'empreses per país que participen en les transaccions. La meta empresarial és garantir que hi hagi almenys 3 empreses participants per país. Per a aconseguir això, serà necessari utilitzar DAX per a calcular i representar aquesta informació de manera clara i concisa.
#
# ![image-5.png](attachment:image-5.png)
#
# Como se puede observar existen solo 2 países en los que no se cumplen : China y España, se recomienda incentivar la incorporación de nuevas empresas en estos dos mercados y en el mercado Frances (que cumplió el objetivo con apenas con 3 empresas participantes) ya que de estos datos se puede interpretar que existe un mercado potencialmente explotable.
#
# Codigo DAX de las medidas:
#
# ``
# countemp = var x = DISTINCTCOUNT('S4 transactions'[business_id]) return IF(ISBLANK(x),0,x)
# ``
#
#
# ``
# EmpXpais =
#  3
# ``
#
# ### Exercici 6
# Crea una nova KPI que permeti visualitzar la quantitat de transaccions declinades al llarg del temps. L'empresa va establir un objectiu de tenir menys de 10 transaccions declinades per mes.
#
# ![image-19.png](attachment:image-19.png)
#
# En este caso tenemos 3 meses en los que hay mas de 10 transacciones rechazadas: Abril Mayo y Junio del 2021, lo particular es que son 3 meses consecutivos (y son los unicos meses en los que no se cumple con el objetivo). Con lo cual se recomienda investigar el rendimiento de las transacciones en esos meses especificos para identificar el o los causantes de esta situación.
#
# Codigo DAX de las medidas:
#
# ``
# declin = var x = sum('S4 transactions'[declined]) return IF(ISBLANK(x),0,x)
# ``
#
# ``
# Objetivo ej 6 nivel 1 =
#  10
# ``
#
#
#
# ### Exercici 7
# Crea un gràfic de columnes agrupades que reflecteixi la sumatòria de les vendes per mes. L'objectiu de l'empresa és tenir almenys 10.000 transaccions per mes.
#
# ![image-6.png](attachment:image-6.png)
#
# En este caso se puede ver que el objetivo se ha cumplido solo en 7 de los 13 meses de los que se tienen datos, se recomienda evaluar si el objetivo es adecuado para este caso, de ser adecuado se recomienda enfocar los esfuerzos empresariales a incentivar las ventas en los meses en los que no se cumple con el objetivo.
#
# Codigo DAX de las medidas:
#
# ``
# SumaVentas = var x = CALCULATE(sum('S4 transactions'[amount]), 'S4 transactions'[declined] = 0) return IF(ISBLANK(x),0, x)
# ``
#
# ``
# KPI5 =
# 10000
# ``
#
# ### Exercici 8
# En aquest exercici, es vol aprofundir en les transaccions realitzades per cada usuari/ària i presentar la informació de manera clara i comprensible. En una taula, presenta la següent informació: - Nom i cognom dels usuaris/es (caldrà crear una nova columna que combini aquesta informació). - Edat dels usuaris/es. - Mitjana de les transaccions en euros. - Mitjana de les transaccions en dòlars (conversió: 1 euro equival a 1,08 dòlars). S'han de fer els canvis necessaris per a identificar als usuaris/es que van tenir una mitjana de 300 o més euros i 320 o més dòlars en les seves transaccions.
#
# ![image-7.png](attachment:image-7.png)
#
# De esta tabla se pueden obtener varias conclusiones:
# 1º: existen bastantes usuarios que no tienen transacciones realizadas, se recomienda evaluar algún tipo de incentivo o publicidad personalizada (si las condiciones legales de la relacion usuario/ empresa lo permite) para motivar el consumo para estos usuarios.
# 2º: El rango etario de nuestros usuarios va de los 23 a los 45 años, se recomienda tener en cuenta esta información a la hora de planear campañas de marketing especializadas o enfocadas a un grupo en particular.
# 3º: El mayor monto medio en euros es de 494.82 y en dolares es de 534.41 y el de menor monto medio(de los que tienen alguna transacción) es de 18.08 en euros y 19.53 en dolares.
# Con lo cual podemos asegurar que hay un rango de precios muy amplio.
# 4º Haciendo un analisis rapido se puede identificar que existen muchas mas transacciones cuyo monto medio es menor a 300 euros y 320 dolares que las que son mayores o iguales a estos montos. Es importante tener en cuenta esto a la hora de negociar productos y precios a ingresar en el mercado.
#
# Codigo DAX de la columna calculada de Nombre completo:
#
# ``
# Nombre Completo = 'S4 users'[Name] & " " & 'S4 users'[surname]
# ``
#
#
# Aqui los pasos que seguí para obtener la columna Edad de los usuarios:
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
# Codigos DAX :
#
# ``
# En Dolares = var x = AVERAGE('S4 transactions'[amount]) * 1.08 return IF(ISBLANK(x),0,x)
# ``
#
# ``
# Monto medio en euros = var x = AVERAGE('S4 transactions'[amount]) return IF(ISBLANK(x),0,x)
# ``
#
# ``
# mayor_300 = var x = IF(AVERAGE('S4 transactions'[amount]) >= 300, "Mayor o igual que 300", "Menor que 300") return IF(ISBLANK(x),0,x)
# ``
#
# ``
# mayor_320 = IF(AVERAGEX('S4 transactions', 'S4 transactions'[amount] * 1.08) >= 320, "Mayor o igual que 320", "Menor que 320")
# ``
# ### Exercici 9
# Redacta un paràgraf breu, de màxim 50 paraules, explicant el significat de les xifres presentades en les visualitzacions de Power BI. Pots interpretar les dades en general o centrar-te en algun país específic. Acompanya les interpretacions realitzades amb la captura de pantalla de les visualitzacions que analitzaràs.
#
# En esta imagen,destaco que en la mayoria de los casos se han cumplido los objetivos, y cuando no ha sido asi,  ha sido por un pequeño margen, por lo cual interpreto que los objetivos diseñados son alcanzables y los aspectos a mejorar estan del lado del desempeño empresarial.
#
# ![image-13.png](attachment:image-13.png)
#
# # NIVEL 2
#
# ### Exercici 1
# Des de l'àrea de màrqueting necessiten examinar la tendència mensual de les transaccions realitzades l'any 2021, específicament, volen conèixer la variació de les transaccions en funció del mes. Recorda visualitzar la meta empresarial d'aconseguir almenys 12.500 transaccions per mes. En aquest exercici, serà necessari que s'aconsegueixi identificar els mesos en què no es va aconseguir la meta establerta. De ser necessari pots realitzar dues visualitzacions.
#
# ![image-14.png](attachment:image-14.png)
#
# Como se puede observar, la variación mensual es muy alta, sobre todo si tenemos en cuenta que el menor monto mensual son 6.500 euros y el mayor monto mensual son 15.980 euros.
# Tambien debemos destacar que de los 10 meses analizados 5 no cumplen con el objetivo.
# Se recomienda tomar las decisiones empresariales necesarias para que la variacion mensual no sea tan amplia y para que el objetivo mensual sea alcanzable.
#
# Codigo DAX del Objetivo:
#
# ``
# KPItendencia = 12500
# ``
#
# ### Visualización de los meses en los cuales no se ha conseguido cumplir con el objetivo establecido:
#
#
# ![image-15.png](attachment:image-15.png)
#
# Como se puede observar, en 3 de los 5 analizados el monto mensual no esta tan alejado del objetivo. Se recomienda tener esto en cuenta para poder incentivar el crecimiento del monto mensual para estos casos.
#
# ### Exercici 2
# En el teu treball, es vol aprofundir en la comprensió de les transaccions realitzades a Alemanya. Per tant, et sol·liciten que desenvolupis mesures DAX per a crear visualitzacions que destaquin la mitjana de vendes a Alemanya. Tingues present que l'empresa té com a objectiu aconseguir una xifra de 250 euros anuals. Configura la visualització de manera que el valor mínim sigui 100 i el màxim 350, brindant així una representació més efectiva de la informació.
#
# ### Año 2021
#
# ![image-16.png](attachment:image-16.png)
#
# En este año se ha cumplido con el objetivo anual, aunque por un margen muy pequeño. Se recomienda tener presente esto a la hora de tomar decisiones empresariales que puedan afectar negativamente al monto medio en este mercado
#
# Codigo DAX medida de ventas en Alemania 2022:
#
# ``
# MedAlemania2022 = CALCULATE (AVERAGE('S4 transactions'[amount]), 'S4 companies'[country] = "Germany", YEAR('S4 transactions'[timestamp]) = 2021)
# ``
#
#
# ### Año 2022
#
# ![image-17.png](attachment:image-17.png)
#
# En este caso no se ha cumplido con el objetivo anual. Se recomienda analizar mas a fondo por qué se ha dado este desmpeño y exporar opciones empresariales que puedan revertir esta situación.
#
# Codigo DAX medida de ventas en Alemania 2022:
#
# ``
# MedAlemania2022 = CALCULATE (AVERAGE('S4 transactions'[amount]), 'S4 companies'[country] = "Germany", YEAR('S4 transactions'[timestamp]) = 2022)
# ``
#
# ### Exercici 3
# Escriu un breu paràgraf, màxim de 25 paraules, indica en quin mes no es va arribar a complir amb l'objectiu proposat de l'exercici 1.
#
# En los meses de Marzo, Julio, Septiembre, Octubre y Noviembre no se ha cumplido con el objetivo propuesto.
#
# # NIVEL 3
#
# ### Exercici 1
# La secció de màrqueting vol aprofundir en les transaccions realitzades pels usuaris i usuàries. En conseqüència, se't sol·licita l'elaboració de diverses visualitzacions que incloguin:
#
# Les mesures estadístiques claus de les variables que consideris rellevants per a comprendre les transaccions realitzades pels usuaris/es.
# Quantitat de productes comprats per cada usuari/ària.
# Mitjana de compres realitzades per usuari/ària, visualitza quins usuaris/es tenen una mitjana de compres superior a 150 i quins no.
# Mostra el preu del producte més car comprat per cada usuari/ària.
# Visualitza la distribució geogràfica dels usuaris/es.
# En aquesta activitat, serà necessari que realitzis els ajustos necessaris en cada gràfic per a millorar la llegibilitat i comprensió. En el compliment d'aquesta tasca, s'espera que avaluïs acuradament quines variables són rellevants per a transmetre la informació requerida de manera efectiva.
#
# ![image-8.png](attachment:image-8.png)
#
# Haciendo un analisis rapido de las dos visualizaciones presentes podemos presentar varias conclusiones:
#
# 1º La mayor cantidad de usuarios se dan en estados unidos, Reino Unido y Canada. Se recomienda tener en cuenta esta información a la hora de tomar decisiones que puedan afectar a estos mercados.
#
# 2º El precio del producto mas caro comprado es de 195.94 euros. Se recomienda tener esto en cuenta a la hora de introducir nuevos productos al mercado.
#
# 3º Hay una gran cantidad de usuarios cuyo producto mas caro tiene un precio mayor a 100 euros. Es recomendable tener presente esta información cuando se ingresen nuevos productos al mercado.
#
# 4º Tambien hay una mayoria de usuarios cuyo monto promedio gastado es mayor a 100 euros. Esta información es util para conocer el poder adquisitivo promedio de nuestros usuarios.
#
# 5º La mayoria de los usuarios han comprado menos de 10 productos. Esto es importante a la hora de conocer y reforzar la fidelidad de nuestros clientes.
#
# Codigo DAX de la medida para obtener el producto mas caro que ha comprado cada usuario:
#
# ``
# ProdMasCaro =
# CALCULATE(
#     MAX('S4 products'[price - Copy]),
#     'S4 transactions'[declined] = 0,
#     CROSSFILTER('S4 product_transaction'[idProducto], 'S4 products'[id], Both)
# )
# ``
#
# Codigo DAX para obtener las compras por usuario:
#
# ``
# comprasXusuario = CALCULATE(COUNT('S4 product_transaction'[idProducto]), 'S4 transactions'[declined] = 0)
# ``
# Codigo DAX para obtener dos columnas a traves de un condicional que separe la media de monto por usario en mayores a 150 o menores o iguales que 150:
#
# ``
# Mayor150 = IF('S4 users'[mediaMontoUsuario] > 150, "Mayor que 150", "Menor o igual que 150")
# ``
#
# Codigo DAX para obtener la media de monto por usuario:
#
# ``
# mediaMontoUsuario = CALCULATE(AVERAGE('S4 transactions'[amount]), 'S4 transactions'[declined] =0)
# ``
