# %% [markdown]
# # Nivell 1
# ## Els 7 exercicis del nivell 1 de la tasca 01
# ### Ex 1

# %% [markdown]
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(amount)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# sns.histplot(data = dataset["amount"] )
# plt.title("Frecuencia de montos en transacciones")
# plt.xlabel("valor")
# plt.ylabel("frecuencia")
# plt.show()
# ```

# %% [markdown]
# ### Ex 2
#
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(weight, price - Copy)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# sns.boxplot(data= dataset, x="weight", y= "Fprice" )
# plt.ylabel("precio")
# plt.xlabel("peso")
# plt.title("Comparación de peso y precios")
# plt.show()
# ```

# %% [markdown]
# ### Ex 3
#
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(country)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# dataset.groupby("country").size().plot(kind="pie", autopct="%1.1f%%",figsize=(10,6))
# plt.title("Porcentaje de usuarios por país")
# plt.show()
# ```

# %% [markdown]
# ### Ex 4
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(undefined, undefined.1)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# sns.set_theme("paper")
# sns.set_style("darkgrid")
#
#
#
#
# plt.figure(figsize=(10, 6))
# sns.barplot(data= dataset , x= "country", y= "id")
#
# plt.show()
# ```

# %% [markdown]
# ### Ex 5
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# sns.countplot(data = dataset, x = "country", hue = "declined")
# plt.ylabel("cantidad")
# plt.xlabel("País")
# plt.title("cantidad de transacciones declinadas y aceptadas por País")
# plt.show()
# ```

# %% [markdown]
# ### Ex 6
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
#
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(undefined, undefined.1, undefined.2)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# dataset = dataset.sort_values(by="country")
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# sns.lineplot(data = dataset, x = "country", y ="amount", hue = "declined")
# plt.xticks(rotation =90)
# plt.show()
#
# ```

# %% [markdown]
# ### Ex 7
# ![image.png](attachment:image.png)
#
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(Fprice, weight)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# sns.pairplot(dataset,vars =["Fprice", "weight"])
# plt.show()
#
#
#
# ```

# %% [markdown]
# # Nivell 2
# ### Ex 1
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(undefined, undefined.1, undefined.2)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# corr_matrix = dataset.corr()
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# plt.figure(figsize=(8, 6))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5,mask=np.triu(np.ones_like(dataset.corr(),dtype=bool)))
# plt.title('Heatmap de Matriz de Correlación')
# plt.show()
# ```

# %% [markdown]
# ### Ex 2
# ![image.png](attachment:image.png)
#
# codigo para representar la visualización en power bi:
#
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(undefined, undefined.1)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# dataset.columns =["Cantidad De Productos", "Monto"]
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# sns.jointplot(x = "Monto", y ="Cantidad De Productos", data = dataset)
# plt.show()
# ```

# %% [markdown]
# # Nivell 3
# ### Ex 1
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(undefined, undefined.1)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
#
# fig, axes=plt.subplots()
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# sns.violinplot(dataset,
#               x="declined",
#                y="amount",
#                color="blue"
#                )
# sns.stripplot(dataset,
#               x="declined",
#               y="amount",
#               hue="declined",
#               palette="Spectral")
# plt.show()
#
#
# ```

# %% [markdown]
# ### Ex 2
# ![image.png](attachment:image.png)
# codigo para representar la visualización en power bi:
# ```
# # The following code to create a dataframe and remove duplicated rows is always executed and acts as a preamble for your script:
#
# # dataset = pandas.DataFrame(undefined, undefined.1, undefined.2)
# # dataset = dataset.drop_duplicates()
#
# # Paste or type your script code here:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# g = sns.FacetGrid(dataset, col="declined",  row="country")
# sns.set_theme("paper")
# sns.set_style("darkgrid")
# g.map_dataframe(sns.swarmplot, x="amount")
# g.set_axis_labels("Monto", "Distribución de Transacciones")
# plt.show()
# ```
